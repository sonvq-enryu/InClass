# %%
import numpy as np
import librosa
import os

# %%
import IPython.display as ipd
# ipd.Audio(audio_path)

# %%
# Load all wav file.
path = "Spoken-Digit-Recognition/new_spoken_digit"
wavs = [wav for wav in os.listdir(path) if wav.split('.')[1] == 'wav']

# %%
def load_file

# %%
for wav in wavs:
    target = wav.split('_')[0]
    feature =
# Out:
# ['0_jackson_25.wav',
#  '5_yweweler_11.wav',
#  '4_yweweler_18.wav',
#  '6_yweweler_21.wav',
#  '9_nicolas_26.wav',
#  '8_jackson_41.wav',
#  '6_nicolas_42.wav',
#  '8_yweweler_27.wav',
#  '3_jackson_25.wav',
#  '8_jackson_31.wav',
#  '6_theo_49.wav',
#  '0_nicolas_44.wav',
#  '8_jackson_19.wav',
#  '5_yweweler_46.wav',
#  '1_theo_45.wav',
#  '3_jackson_14.wav',
#  '9_jackson_29.wav',
#  '2_theo_24.wav',
#  '6_jackson_19.wav',
#  '8_jackson_42.wav',
#  '0_theo_26.wav',
#  '7_yweweler_2.wav',
#  '4_nicolas_47.wav',
#  '9_jackson_16.wav',
#  '8_jackson_44.wav',
#  '8_theo_21.wav',
#  '8_nicolas_22.wav',
#  '7_nicolas_9.wav',
#  '5_nicolas_48.wav',
#  '3_nicolas_7.wav',
#  '5_nicolas_12.wav',
#  '2_yweweler_15.wav',
#  '3_nicolas_8.wav',
#  '3_nicolas_3.wav',
#  '3_jackson_48.wav',
#  '2_jackson_39.wav',
#  '1_jackson_32.wav',
#  '6_yweweler_9.wav',
#  '1_jackson_41.wav',
#  '8_jackson_21.wav',
#  '8_theo_41.wav',
#  '7_nicolas_44.wav',
#  '7_jackson_0.wav',
#  '0_jackson_4.wav',
# ...
